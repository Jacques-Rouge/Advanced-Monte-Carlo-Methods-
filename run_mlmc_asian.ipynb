# %%
from mlmc_functions import run_mlmc, mu_S, sigma_S

# Configuration
T = 1.0              # Time horizon
K = 1.0              # Strike price
M_param = 4.0        # SDE parameter
epsilon = 0.0001     # Target accuracy
max_levels = 10      # Maximum number of levels
N_initial = 10000    # Initial samples per new level
n_asian = 10         # Number of monitoring points for Asian option

# M_base must be divisible by n_asian
M_base = 10  # Level 0: 10 steps, Level 1: 40 steps, Level 2: 160 steps, etc.

    # Run MLMC for Asian option

# %%
results = run_mlmc(
        mu_func=mu_S,
        sigma_func=sigma_S,
        T=T,
        K=K,
        M_param=M_param,
        epsilon=epsilon,
        max_levels=max_levels,
        N_initial=N_initial,
        n_asian=n_asian,
        M_base=M_base,
        verbose=True
    )
    
print(f"\nFinal estimate (Asian option): {results['estimate']:.6f}")
# Out:
# ======================================================================
# MULTILEVEL MONTE CARLO - ASIAN OPTION (n_asian=10)
# ======================================================================
#
# ======================================================================
# LEVEL L = 0
# ======================================================================
# Step 2: Initial sampling (N=10000, M=10)
#   E[P_0] = 0.126219, Var[P_0] = 0.050635
#
# Step 3: Optimal sample allocation
#   Level 0: N_opt = 10,127,057 (current = 10,000)
#
# Step 4: Adding extra samples
#   Level 0: +10,117,057 samples
#
# ======================================================================
# LEVEL L = 1
# ======================================================================
# Step 2: Initial sampling (N=10000, M_c=10, M_f=40)
#   E[P_1 - P_0] = -0.000319, Var = 0.000689
#
# Step 3: Optimal sample allocation
#   Level 0: N_opt = 12,488,921 (current = 10,127,057)
#   Level 1: N_opt = 728,177 (current = 10,000)
#
# Step 4: Adding extra samples
#   Level 0: +2,361,864 samples
#   Level 1: +718,177 samples
#
# ======================================================================
# LEVEL L = 2
# ======================================================================
# Step 2: Initial sampling (N=10000, M_c=40, M_f=160)
#   E[P_2 - P_1] = 0.000041, Var = 0.000178
#
# Step 3: Optimal sample allocation
#   Level 0: N_opt = 14,891,403 (current = 12,488,921)
#   Level 1: N_opt = 868,256 (current = 728,177)
#   Level 2: N_opt = 220,797 (current = 10,000)
#
# Step 4: Adding extra samples
#   Level 0: +2,402,482 samples
#   Level 1: +140,079 samples
#   Level 2: +210,797 samples
#
# Step 5: Convergence test (Equation 10)
#   Max(|Y_1|/M, |Y_2|) = 1.167179e-04
#   Threshold = 2.121320e-04
#   ✓ CONVERGED
#
# ======================================================================
# RESULTS
# ======================================================================
#
# Option Price: 0.126575
# Levels: 3
# Total samples: 15,980,456
# Epsilon: 0.0001
#
# Sample distribution:
#   Level 0: 14,891,403 samples
#   Level 1: 868,256 samples
#   Level 2: 220,797 samples
# ======================================================================
#
# Final estimate (Asian option): 0.126575
